# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
games = pd.read_csv('games_data.csv', index_col=0)

# %%
games.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1     1
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0     0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0     0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0     0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0     0
#
#    season             team
# ...

# %%
games.shape
# Out:
# (2166, 27)

# %%
games.info
# Out:
# <bound method DataFrame.info of           date   time            comp         round  day venue result  gf  ga  \
# 1   2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3   2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
# ...

# %% [markdown]
# #checking missing value

# %%
# know how many games we have for each team
games['team'].value_counts()
# Out:
# Manchester City             114
# Tottenham Hotspur           114
# Everton                     114
# West Ham United             114
# Arsenal                     114
# Chelsea                     114
# Crystal Palace              114
# Wolverhampton Wanderers     114
# Manchester United           114
# Aston Villa                 114
# Brighton and Hove Albion    114
# Liverpool                   114
# Newcastle United            114
# Leicester City               76
# Burnley                      76
# Leeds United                 76
# Southampton                  76
# Brentford                    76
# Fulham                       76
# Nottingham Forest            38
# Bournemouth                  38
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Sheffield United             38
# Name: team, dtype: int64

# %%
games['round'].value_counts()
# Out:
# Matchweek 1     57
# Matchweek 30    57
# Matchweek 23    57
# Matchweek 12    57
# Matchweek 24    57
# Matchweek 25    57
# Matchweek 26    57
# Matchweek 27    57
# Matchweek 29    57
# Matchweek 31    57
# Matchweek 2     57
# Matchweek 33    57
# Matchweek 34    57
# Matchweek 28    57
# Matchweek 35    57
# Matchweek 36    57
# Matchweek 37    57
# Matchweek 32    57
# Matchweek 22    57
# Matchweek 21    57
# Matchweek 7     57
# Matchweek 20    57
# Matchweek 3     57
# Matchweek 4     57
# Matchweek 5     57
# Matchweek 6     57
# Matchweek 8     57
# Matchweek 9     57
# Matchweek 10    57
# Matchweek 11    57
# Matchweek 13    57
# Matchweek 14    57
# Matchweek 15    57
# Matchweek 16    57
# Matchweek 17    57
# Matchweek 18    57
# Matchweek 19    57
# Matchweek 38    57
# Name: round, dtype: int64

# %%
games[games['team'] == 'Liverpool']
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D   2   2
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D   1   1
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L   1   2
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   9   0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W   2   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W   2   0
# 49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W   4   2
# 50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W   2   1
# 51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W   3   0
# 52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   2   0
#
# ...

# %% [markdown]
# # Cleaning Data

# %%
games.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
# convert a date into numerical value
games['date'] = pd.to_datetime(games['date'])

# %%
games
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
# ...

# %%
games.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
# convert "venue" coulmn into numerical value
# convert from string to categories then to numbers
games['venue_num'] = games['venue'].astype('category').cat.codes

# %%
games['opponent_num'] = games['opponent'].astype('category').cat.codes

# %%
# ading time_hour column which get rid of mins then convert it into intger
games['time_hour'] = games['time'].str.replace(':.+', '', regex=True).astype('int')

# %%
games['day_num'] = games['date'].dt.day_of_week

# %%
games['target'] = (games['result'] == 'W').astype('int')

# %%
games
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
# ...

# %%
games.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# venue_num                 int8
# opponent_num              int8
# time_hour                int32
# ...

# %% [markdown]
# # ML Models

# %%
rfc = RFC(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = games[games['date'] < '2022-01-01']

# %%
test = games[games['date'] > '2022-01-01']

# %%
predictors = ['venue_num', 'opponent_num', 'time_hour', 'day_num']

# %%
rfc.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rfc.predict(test[predictors])

# %%
acc = accuracy_score(test['target'], preds)

# %%
acc
# Out:
# 0.5889748549323017

# %% [markdown]
# ### dig dipper

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0    1
# actual
# 0           487  121
# 1           304  122

# %% [markdown]
# As we can see above the model prediction was good in losess cases (0) but we care about is the win so gonna try diffrent method

# %%
precision_score(test['target'], preds)
# Out:
# 0.5020576131687243

# %% [markdown]
# ### improving precision

# %% [markdown]
# grouped_games = games.groupby

# %%
grouped_games = games.groupby('team')

# %%
group = grouped_games.get_group('Arsenal')

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W   2   0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   2
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W   3   0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W   2   1
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   2   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2021-05-02  14:00  Premier League  Matchweek 34  Sun  Away      W   2   0
# 54 2021-05-09  19:00  Premier League  Matchweek 35  Sun  Home      W   3   1
# 55 2021-05-12  20:15  Premier League  Matchweek 36  Wed  Away      W   1   0
# 56 2021-05-19  19:00  Premier League  Matchweek 37  Wed  Away      W   3   1
# 57 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   2   0
#
# ...

# %%
def rol_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rol_stats = group[cols].rolling(3, closed='left').mean() # take the current week out
    group[new_cols] = rol_stats
    group = group.dropna(subset=new_cols) # drop any missing value
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk','pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rol_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 44 2023-05-02  20:00  Premier League  Matchweek 34  Tue  Home      W   3   1
# 45 2023-05-07  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 46 2023-05-14  16:30  Premier League  Matchweek 36  Sun  Home      L   0   3
# 47 2023-05-20  17:30  Premier League  Matchweek 37  Sat  Away      L   0   1
# 48 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      W   5   0
#
# ...

# %%
games_rolling = games.groupby('team').apply(lambda x: rol_averages(x, cols, new_cols)) # applying a function to each team

# %%
games_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 39 2023-04-29  15:00  Premier League  Matchweek 34
#                         40 2023-05-06  15:00  Premier League  Matchweek 35
#                         41 2023-05-13  15:00  Premier League  Matchweek 36
#                         42 2023-05-20  15:00  Premier League  Matchweek 37
#                         43 2023-05-28  16:30  Premier League  Matchweek 38
#
# ...

# %%
games_rolling = games_rolling.droplevel('team') # drop index level (team)

# %%
games_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 39 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0   6
# 40 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1   0
# 41 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0   2
# 42 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1   1
# 43 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   5
#
# ...

# %%
games_rolling.index = range(games_rolling.shape[0]) # assign new indices to have uniqe value for each index

# %%
games_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 2083 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0
# 2084 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1
# 2085 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0
# 2086 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1
# 2087 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0
#
# ...

# %% [markdown]
# ### Retrain The Model

# %%
def make_predictions(data, predictors):
    train = data[data['date'] < '2022-01-01']
    test = data[data['date'] > '2022-01-01']
    rfc.fit(train[predictors], train['target'])
    preds = rfc.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], predicted = preds), index=test.index)
    precision = precision_score(test['target'], preds)
    return combined, precision

# %%
combined, precision = make_predictions(games_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5474137931034483

# %%
combined
# Out:
#       actual  predicted
# 55         0          1
# 56         1          0
# 57         1          0
# 58         1          1
# 59         1          1
# ...      ...        ...
# 2083       0          0
# 2084       1          0
# 2085       0          0
# 2086       0          0
# 2087       0          0
#
# [1028 rows x 2 columns]

# %%
combined = combined.merge(games_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 55         0          1 2022-01-23                  Arsenal         Burnley
# 56         1          0 2022-02-10                  Arsenal          Wolves
# 57         1          0 2022-02-19                  Arsenal       Brentford
# 58         1          1 2022-02-24                  Arsenal          Wolves
# 59         1          1 2022-03-06                  Arsenal         Watford
# ...      ...        ...        ...                      ...             ...
# 2083       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 2084       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 2085       0          0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 2086       0          0 2023-05-20  Wolverhampton Wanderers         Everton
# 2087       0          0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result
# 55        D
# 56        W
# 57        W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    'Brighton and Hove Albion': 'Brighton',
    'Manchester United': 'Manchester UTD',
    'Newcastle United' : 'Newcastle UTD',
    'Tottenham Hotspur' : 'Tottenham',
    'West Ham United' : 'West Ham',
    'Wolverhampton Wanderers': 'Wolves'
}
mapping = MissingDict(**map_values)

# %%
mapping['Arsenal']
# Out:
# 'Arsenal'

# %%
mapping['West Ham United']
# Out:
# 'West Ham'

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 55         0          1 2022-01-23                  Arsenal         Burnley
# 56         1          0 2022-02-10                  Arsenal          Wolves
# 57         1          0 2022-02-19                  Arsenal       Brentford
# 58         1          1 2022-02-24                  Arsenal          Wolves
# 59         1          1 2022-03-06                  Arsenal         Watford
# ...      ...        ...        ...                      ...             ...
# 2083       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 2084       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 2085       0          0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 2086       0          0 2023-05-20  Wolverhampton Wanderers         Everton
# 2087       0          0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result new_team
# 55        D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=['date', 'new_team'], right_on=['date', 'opponent'])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2022-01-23                  Arsenal
# 1           1            0 2022-02-10                  Arsenal
# 2           1            0 2022-02-19                  Arsenal
# 3           1            1 2022-02-24                  Arsenal
# 4           1            1 2022-03-06                  Arsenal
# ..        ...          ...        ...                      ...
# 784         0            0 2023-04-29  Wolverhampton Wanderers
# 785         1            0 2023-05-06  Wolverhampton Wanderers
# 786         0            0 2023-05-13  Wolverhampton Wanderers
# 787         0            0 2023-05-20  Wolverhampton Wanderers
# 788         0            0 2023-05-28  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0           Burnley        D    Arsenal         0            0
# 1            Wolves        W    Arsenal         0            0
# ...

# %%
merged[(merged['predicted_x'] == 1) & (merged['predicted_y'] == 0)] ['actual_x'].value_counts()
# Out:
# 1    84
# 0    68
# Name: actual_x, dtype: int64

# %%
84 / 152
# Out:
# 0.5526315789473685
